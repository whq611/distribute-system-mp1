# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
lists = []
for i in range(8):
    with open("node" + str(i) + ".txt", "r") as fs:
        lists.append([])
        flag = False
        for line in fs:
            #print(line)
            if str(line) == "BANDWIDTH: \n":
                flag = True
                continue
            if line == "DELAY: \n":
                flag = False
            if flag:
                if line != "\n":
                    lists[i].append(float(line.split()[0]))

# %%
a = np.array(lists)
plt.figure(figsize=(20,10))
for i in range(8):
    plt.plot(a[i]) 
plt.legend(['node0', 'node1', 'node2','node3', 'node4', 'node5','node6', 'node7'])
plt.xlabel('time(s)')
plt.ylabel('Bandwidth(ms)')
plt.title('Evaluation bandwidth')
# Out:
# Text(0.5,1,'Evaluation bandwidth')

# %%
temp = []
for i in range(8):
    with open("node" + str(i) + ".txt", "r") as fs:
        lists.append([])
        flag = False
        for line in fs:
            #print(line)
            if line == "DELAY: \n":
                flag = True
                continue
            if flag:
                if line != "\n":
                    lists[i].append(float(line.split()[0]))

# %%
b = np.array(lists)
plt.figure(figsize=(20,10))
for i in range(8):
    plt.plot(100, a[i][0:99])
plt.legend(['node0', 'node1', 'node2'])
plt.xlabel('time(s)')
plt.ylabel('Bytes)')
plt.title('Evaluation Delay')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-0e4ef7a5c69e> in <module>()
#       2 plt.figure(figsize=(20,10))
#       3 for i in range(8):
# ----> 4     plt.plot(100, a[i][0:99])
#       5 plt.legend(['node0', 'node1', 'node2'])
#       6 plt.xlabel('time(s)')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
# ...
